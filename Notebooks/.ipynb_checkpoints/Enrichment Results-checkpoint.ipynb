# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import json
import os
import random
from tabulate import tabulate

# %%
def make_main_df_no_category(root_folder):
    
    """
    
    creates a pd.DataFrame from all the enriched verdicts
    
    :param root_folder - the folder that contains all the verdics
    
    :returns pd.DataFrame with the following atrributes:
    
        * defense, petitioners, judges, defense_attorney, petitioner_attorney and all the normalized values of them.
        * category
    
    """
    
    ids = list()
    summary = list()
    petitioner = list()
    petitioner_normalized = list()
    defense = list()
    defense_normalized = list()
    judges = list()
    judges_normalized = list()
    petitioner_attorneys = list()
    petitioner_attorneys_normalized = list()
    defense_attorneys = list()
    defense_attorneys_normalized = list()
    
    
    for verdict in os.listdir(root_folder):
        
        cur_path = root_folder + '/' + verdict
        
        with open(cur_path, 'r',encoding = 'utf-8' ) as file:
            
            verdict_json = json.load(file)
            
            ids.append(verdict_json['_id'])
            summary.append(verdict_json["_source"]["doc"]["Doc Details"]["סיכום"])
            
            petitioner.append(verdict_json["_source"]["doc"]["Doc Details"]["העותר"])
            petitioner_normalized.append(verdict_json["_source"]["doc"]["Doc Details"]['העותר מנורמל'])
            
            defense.append(verdict_json["_source"]["doc"]["Doc Details"]["המשיב"])
            defense_normalized.append(verdict_json["_source"]["doc"]["Doc Details"]['המשיב מנורמל'])
            
            judges.append(verdict_json["_source"]["doc"]["Doc Details"]["לפני"])
            judges_normalized.append(verdict_json["_source"]["doc"]["Doc Details"]['לפני מנורמל'])
            
            petitioner_attorneys.append(verdict_json["_source"]["doc"]["Doc Details"]["בשם העותר"])
            petitioner_attorneys_normalized.append(verdict_json["_source"]["doc"]["Doc Details"]['בשם העותר מנורמל'])
            
            defense_attorneys.append(verdict_json["_source"]["doc"]["Doc Details"]["בשם המשיב"])
            defense_attorneys_normalized.append(verdict_json["_source"]["doc"]["Doc Details"]['בשם המשיב מנורמל'])            


    df = pd.DataFrame(columns=['id','summary','petitioner','petitioner_normalized', 'defense', 
                               'defense_normalized', 'judges', 'judges_normalized', 'petitioner_attorneys', 
                               'petitioner_attorneys_normalized', 'defense_attorneys', 'defense_attorneys_normalized'], 
                      data = list(zip(ids, summary, petitioner, petitioner_normalized, defense, 
                                defense_normalized, judges, judges_normalized, petitioner_attorneys, 
                                petitioner_attorneys_normalized, defense_attorneys, defense_attorneys_normalized)))
    
    return df

# %%
def make_main_df(root_folder):
    
    """
    
    creates a pd.DataFrame from all the enriched verdicts
    
    :param root_folder - the folder that contains all the verdics
    
    :returns pd.DataFrame with the following atrributes:
    
        * defense, petitioners, judges, defense_attorney, petitioner_attorney and all the normalized values of them.
        * category
    
    """
    
    ids = list()
    summary = list()
    category = list()
    petitioner = list()
    petitioner_normalized = list()
    defense = list()
    defense_normalized = list()
    judges = list()
    judges_normalized = list()
    petitioner_attorneys = list()
    petitioner_attorneys_normalized = list()
    defense_attorneys = list()
    defense_attorneys_normalized = list()
    
    
    for verdict in os.listdir(root_folder):
        
        cur_path = root_folder + '/' + verdict
        
        with open(cur_path, 'r',encoding = 'utf-8' ) as file:
            
            verdict_json = json.load(file)
            
            ids.append(verdict_json['_id'])
            summary.append(verdict_json["_source"]["doc"]["Doc Details"]["סיכום"])
            category.append(verdict_json['_source']['doc']['Case Details']['Category'])
            
            petitioner.append(verdict_json["_source"]["doc"]["Doc Details"]["העותר"])
            petitioner_normalized.append(verdict_json["_source"]["doc"]["Doc Details"]['העותר מנורמל'])
            
            defense.append(verdict_json["_source"]["doc"]["Doc Details"]["המשיב"])
            defense_normalized.append(verdict_json["_source"]["doc"]["Doc Details"]['המשיב מנורמל'])
            
            judges.append(verdict_json["_source"]["doc"]["Doc Details"]["לפני"])
            judges_normalized.append(verdict_json["_source"]["doc"]["Doc Details"]['לפני מנורמל'])
            
            petitioner_attorneys.append(verdict_json["_source"]["doc"]["Doc Details"]["בשם העותר"])
            petitioner_attorneys_normalized.append(verdict_json["_source"]["doc"]["Doc Details"]['בשם העותר מנורמל'])
            
            defense_attorneys.append(verdict_json["_source"]["doc"]["Doc Details"]["בשם המשיב"])
            defense_attorneys_normalized.append(verdict_json["_source"]["doc"]["Doc Details"]['בשם המשיב מנורמל'])            


    df = pd.DataFrame(columns=['id','summary','category','petitioner','petitioner_normalized', 'defense', 
                               'defense_normalized', 'judges', 'judges_normalized', 'petitioner_attorneys', 
                               'petitioner_attorneys_normalized', 'defense_attorneys', 'defense_attorneys_normalized'], 
                      data = list(zip(ids, summary, category,petitioner, petitioner_normalized, defense, 
                                defense_normalized, judges, judges_normalized, petitioner_attorneys, 
                                petitioner_attorneys_normalized, defense_attorneys, defense_attorneys_normalized)))
    
    return df

# %%
df = make_main_df('C:/HebrewCourtVerdictsAnalyzer/ML/Pipeline Python Scripts/clas_out')

# %%
not_normalized = df.drop(columns=['id','summary','petitioner_normalized','defense_normalized', 'judges_normalized', 'petitioner_attorneys_normalized', 'defense_attorneys_normalized'])

# %%
normalized = df.drop(columns=['id','summary','petitioner','defense', 'judges', 'petitioner_attorneys', 'defense_attorneys'])

# %%
petitioner = not_normalized.loc[:,'petitioner']
defense = not_normalized.loc[:,'defense']
judges = not_normalized.loc[:,'judges']
petitioner_attorneys = not_normalized.loc[:,'petitioner_attorneys']
defense_attorneys = not_normalized.loc[:,'defense_attorneys']

# %%
petitioner_normalized = normalized.loc[:,'petitioner_normalized']
defense_normalized = normalized.loc[:,'defense_normalized']
judges_normalized = normalized.loc[:,'judges_normalized']
petitioner_attorneys_normalized = normalized.loc[:,'petitioner_attorneys_normalized']
defense_attorneys_normalized = normalized.loc[:,'defense_attorneys_normalized']

# %%
def count_personal(df):
    
    """
    
    counts the personal names occurences on the df
    
    :params df - a pd.DataFrame
    
    :resturns - name to apperenaces dict
    
    """
    
    count_dict = dict()
    
    for row in df:
        if row != None:
            for name in row:
            
                try:
                    count_dict[name] += 1
            
                except KeyError:
                    if name != '':
                        count_dict[name] = 1
    
    return count_dict

# %%
def create_top_k_attenders(df,K):
    
    count_dict = count_personal(df)
    sorted_dict = {k: v for k, v in reversed(sorted(count_dict.items(), key=lambda item: item[1]))}
    dict_itemes = sorted_dict.items()
    topk = list(dict_itemes)[:K]
    names = [name[0][::-1] for name in topk]
    values = [value[1] for value in topk]
    
    return names,values

# %%
def plot(names,values,role):
    x_width = .5

    fig = plt.figure()
    ax = fig.add_axes([0,0,2.5,2.5])
    ax.set_ylabel('Verdicts Count',Fontsize=20)
    ax.set_title(f'Top 10 {role}',size=28)
    rect_values = list()
    for (name,value) in zip(names,values):
        rect_values.append(ax.bar(name , value, color = [(random.uniform(150,255)/255,210/255,230/255)], width =x_width))
    
    #ax.set_xticks(np.add(np.arange(len(names)),(x_width//2)))
    #ax.set_xticklabels(names,Fontsize=10)
    ax.set_xticks([])
    legends = [f'{val} : {name}' for (name,val) in zip(names,values)]
    print(legends)
    ax.legend(rect_values,legends, fontsize=20)
    for rects in rect_values:
        autolabel(ax,rects)
    
    plt.show()

# %%
def autolabel(ax,rects):
    # attach some text labels
    for rect in rects:
        height = rect.get_height()
        ax.text(rect.get_x() + rect.get_width()/2., 0.5*height,
                '%d' % int(height),
                ha='center', va='bottom',fontsize=16,color='black')

# %%
jn_names,jn_values = create_top_k_attenders(judges,10)
plot(jn_names,jn_values,'Judges')
# Out:
# <ipython-input-11-9a41f00c5b25>:6: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   ax.set_ylabel('Verdicts Count',Fontsize=20)
# ["17022 : תויח 'א", "16951 : סינורג 'א", "15200 : שיניב 'ד", "14682 : ןמלגופ 'ע", "13964 : תימע 'י", "13689 : ןייטשניבור 'א", "12782 : ןארבו'ג 'ס", "12560 : רצלמ 'ח", "11239 : רואנ 'מ", "10807 : לדנה 'נ"]

# %%
j_names,j_values = create_top_k_attenders(judges_normalized,10)
plot(j_names,j_values,'Normalized Judges')
# Out:
# <ipython-input-11-9a41f00c5b25>:6: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   ax.set_ylabel('Verdicts Count',Fontsize=20)
# ['17097 : סינורג ןד רשא', '17075 : תויח רתסא', '16118 : שיניב תירוד', '14818 : רואנ םירמ', '14699 : ןמלגופ יזוע', '13981 : תימע קחצי', '13726 : ןייטשניבור םיקילא', '12803 : ןארבוג םילס', '12566 : רצלמ ןנח', '11059 : ןילביר רזעילא']

# %%
pn_names,pn_values = create_top_k_attenders(petitioner,10)
plot(pn_names,pn_values,'Petitioner')
# Out:
# <ipython-input-11-9a41f00c5b25>:6: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   ax.set_ylabel('Verdicts Count',Fontsize=20)
# ['13851 : ינולפ', '12345 : לארשי תנידמ', '4639 : תינולפ', '2262 : רגרבצלז הטול ר"ד לש הדוסימ טרפה תנגהל דקומה', '1356 : לארשי תנידמ ', '650 : ומצעב ', '627 : לארשיב חרזאה תויוכזל הדוגאה', '479 : ומצעב', '456 : מ"עב חוטיבל הרבח סקינפה', '409 : טרפה תנגהל דקומה']

# %%
p_names,p_values = create_top_k_attenders(petitioner_normalized,10)
plot(p_names,p_values,'Normalized Petitioner')
# Out:
# <ipython-input-11-9a41f00c5b25>:6: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   ax.set_ylabel('Verdicts Count',Fontsize=20)
# ['14213 : ינולפ', '13736 : לארשי תנידמ', '4738 : תינולפ', '2304 : רגרבצלז הטול ר"ד לש הדוסימ טרפה תנגהל דקומה', '1129 : ומצעב', '779 : לארשיב חרזאה תויוכזל הדוגאה', '536 : טרפה תנגהל דקומה', '463 : מ"עב חוטיבל הרבח סקינפה', '435 : לארשיב ןוטלשה תוכיא ןעמל העונתה', '353 : מ"עב חוטיבל הרבח ללכ']

# %%
dn_names,dn_values = create_top_k_attenders(defense,10)
plot(dn_names,dn_values,'Defense')
# Out:
# <ipython-input-11-9a41f00c5b25>:6: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   ax.set_ylabel('Verdicts Count',Fontsize=20)
# ['34140 : לארשי תנידמ', '9996 : םינפה רש', '9001 : ינולפ', '6759 : ךילה שגוה', '5432 : םינפה דרשמ', '5400 : לארשי תנידמ ', '5230 : ימשרה םיסכנה סנוכ', '4396 : הלשממל יטפשמה ץעויה', '2834 : תינולפ', '2641 : ןוחטיבה רש']

# %%
d_names,d_values = create_top_k_attenders(defense_normalized,10)
plot(d_names,d_values,'Normalized Defense')
# Out:
# <ipython-input-11-9a41f00c5b25>:6: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   ax.set_ylabel('Verdicts Count',Fontsize=20)
# ['40230 : לארשי תנידמ', '12575 : םינפה רש', '9173 : ינולפ', '6759 : ךילה שגוה', '6074 : םינפה דרשמ', '5915 : הלשממל יטפשמה ץעויה', '5662 : ימשרה םיסכנה סנוכ', '2900 : תינולפ', '2881 : לארשי תרטשמ', '2835 : ןוחטיבה רש']

# %%
pan_names,pan_values = create_top_k_attenders(petitioner_attorneys,10)
plot(pan_names,pan_values,'Petitioner Attorneys')
# Out:
# <ipython-input-11-9a41f00c5b25>:6: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   ax.set_ylabel('Verdicts Count',Fontsize=20)
# ['6247 : ומצעב ', '3656 : ומצעב', '927 : המצעב ', '682 : המצעב', '469 : הנינס ובא ףרשא ד"וע', '426 : םמצעב ', '379 : םמצעב', '307 : ןמדלפ רודגיבא ד"וע', '239 : לטנזור הרדנא ד"וע ', '236 : ןיראב\'ג דומחמ ד"וע']

# %%
pa_names,pa_values = create_top_k_attenders(petitioner_attorneys_normalized,10)
plot(pa_names,pa_values,'Normalized Petitioner Attorneys')
# Out:
# <ipython-input-11-9a41f00c5b25>:6: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   ax.set_ylabel('Verdicts Count',Fontsize=20)
# ['9926 : ומצעב', '1614 : המצעב', '820 : םמצעב', '550 : ןמדלפ רודגיבא', '453 : ןלוג דוד', '411 : לטנזור הרדנא', '398 : ןיראבג דומחמ', '330 : למצ האל', '308 : אגרש דעילא', '289 : ןועבג סומע']

# %%
dan_names,dan_values = create_top_k_attenders(defense_attorneys,10)
plot(dan_names,dan_values,'Defense Attorneys')
# Out:
# <ipython-input-11-9a41f00c5b25>:6: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   ax.set_ylabel('Verdicts Count',Fontsize=20)
# ['969 : ומצעב', '747 : הקיוש יעור ד"וע', '668 : טרב קחצי ד"וע', '612 : ןמלה רנע ד"וע', '606 : סקראמ לאינד ד"וע', '539 : הקיוש יחיבא-יעור ד"וע', '530 : ומצעב ', '525 : ןרע סדה ד"וע', '506 : גרבנזור ןר ד"וע', '495 : ןתיא ידוא ד"וע']

# %%
da_names,da_values = create_top_k_attenders(defense_attorneys_normalized,10)
plot(da_names,da_values,'Normalized Defense Attorneys')
# Out:
# <ipython-input-11-9a41f00c5b25>:6: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   ax.set_ylabel('Verdicts Count',Fontsize=20)
# ['1513 : ומצעב', '1000 : ןמלה רנע', '996 : הקיוש יעור', '884 : טרב קחצי', '798 : סקראמ לאינד', '623 : ןרע סדה', '614 : ןתיא ידוא', '614 : גרבנזור ןר', '609 : ןמריש דעלג', '592 : קפוא ינח']

# %%
petitioner_cat = not_normalized.loc[:,['category', 'petitioner']]
defense_cat = not_normalized.loc[:,['category','defense']]
judges_cat = not_normalized.loc[:,['category','judges']]
petitioner_attorneys_cat = not_normalized.loc[:,['category','petitioner_attorneys']]
defense_attorneys_cat = not_normalized.loc[:,['category','defense_attorneys']]

# %%
petitioner_normalized_cat = normalized.loc[:,['category', 'petitioner_normalized']]
defense_normalized_cat = normalized.loc[:,['category','defense_normalized']]
judges_normalized_cat = normalized.loc[:,['category','judges_normalized']]
petitioner_attorneys_normalized_cat = normalized.loc[:,['category','petitioner_attorneys_normalized']]
defense_attorneys_normalized_cat = normalized.loc[:,['category','defense_attorneys_normalized']]

# %%
def trim_df(series,df,names,col):
    

    new_names = [name[::-1] for name in names]
    dictionary = dict()
    flag = False
    
    for idx,row in series.items():
        
        cur_list = list()
        cur_elements = row
        
        if cur_elements != None:
            for elem in cur_elements:
                if elem != None:
                    if elem != '':
                        
                        for name in new_names:
                            
                            if elem == name:
                                flag = True
                                cur_list.append(elem)
                                break
                                
            if flag == True:
                dictionary[idx] = cur_list
            
            flag = False
    
    trimmed = pd.DataFrame(index=dictionary.keys(),data=dictionary.values())
    trimmed['category'] = df.loc[trimmed.index,['category']]
    #trimmed.reset_index(drop=True, inplace=True)
    categories = ['Family','Labor and Employment','Constitutional','Administrative','Civil','Criminal','International law','National security, military, and the territories','Religious','Social security, Health Insurance, Pension']
    new_columns = new_names + categories
    new_df = pd.DataFrame(columns=new_columns,index=trimmed.index)
    
    for idx in trimmed.index:
        for col in trimmed.columns:
            new_df.at[idx,trimmed.at[idx,col]] = True
    
    new_df.fillna(False,inplace=True)
    new_df.drop(columns=[None],inplace=True)
    
    return new_df

# %%
jn = trim_df(judges,judges_cat,jn_names,'judges')
pn = trim_df(petitioner,petitioner_cat,pn_names,'petitioner')
pan = trim_df(petitioner_attorneys,petitioner_attorneys_cat,pan_names,'petitioner_attorneys')
dn = trim_df(defense,defense_cat,dn_names,'defense')
dan = trim_df(defense_attorneys,defense_attorneys_cat,dan_names,'defense_attorneys')

# %%
j = trim_df(judges_normalized,judges_normalized_cat,j_names,'judges_normalized')
p = trim_df(petitioner_normalized,petitioner_normalized_cat,p_names,'petitioner_normalized')
pa = trim_df(petitioner_attorneys_normalized,petitioner_attorneys_normalized_cat,pa_names,'petitioner_attorneys_normalized')
d = trim_df(defense_normalized,defense_normalized_cat,d_names,'defense_normalized')
da = trim_df(defense_attorneys_normalized,defense_attorneys_normalized_cat,da_names,'defense_attorneys_normalized')

# %%
def top_k_correlated(df,k):
    corr = df.corr()
    #categories = ['Family','Labor and Employment','Constitutional','Administrative','Civil','Criminal','International law','National security, military, and the territories','Religious','Social security, Health Insurance, Pension']
    #corr.drop(categories,inplace=True,axis=0)
    
    pos = (corr.where(np.triu(np.ones(corr.shape), k=1).astype(bool))
                  .stack()
                  .sort_values(ascending=False))
    neg = (corr.where(np.triu(np.ones(corr.shape), k=1).astype(bool))
                  .stack()
                  .sort_values(ascending=True))
    return pos[0:k],neg[0:k]

# %%
def print_top_k(p_series,n_series,role,k):
    print(f'Top {k} {role}')
    table = [pd.DataFrame(p_series),pd.DataFrame(n_series)]
    print(tabulate(table,tablefmt="grid"))
    print()

# %%
k = 30

# %%
pcjn,ncjn = top_k_correlated(jn,k)
pcj,ncj = top_k_correlated(j,k)

pcpn,ncpn = top_k_correlated(pn,k)
pcp,ncp = top_k_correlated(p,k)

pcpan,ncpan = top_k_correlated(pan,k)
pcpa,ncpa = top_k_correlated(pa,k)

pcdn,ncdn = top_k_correlated(dn,k)
pcd,ncd = top_k_correlated(d,k)

pcdan,ncdan = top_k_correlated(dan,k)
pcda,ncda = top_k_correlated(da,k)

# %%
print_top_k(pcjn,ncjn,'Not Normalized Judges',k)
print_top_k(pcj,ncj,'Normalized Judges',k)

print_top_k(pcpn,ncpn,'Not Normalized Petitioners',k)
print_top_k(pcp,ncp,'Normalized Petitioners',k)

print_top_k(pcpan,ncpan,'Not Normalized Petitioners Attorneys',k)
print_top_k(pcpa,ncpa,'Normalized Petitioners Attorneys',k)

print_top_k(pcdn,ncdn,'Not Normalized Defense',k)
print_top_k(pcd,ncd,'Normalized Defense',k)

print_top_k(pcdan,ncdan,'Not Normalized Defense Attorneys',k)
print_top_k(pcda,ncda,'Normalized Defense Attorneys',k)
# Out:
# Top 30 Not Normalized Judges
# +----------------------------------------------------------------------------------------------------------------+
# | ד' ביניש       Labor and Employment                                0.136944                                    |
# |                Constitutional                                      0.111086                                    |
# | ס' ג'ובראן     Criminal                                            0.099435                                    |
# | י' עמית        Civil                                               0.098333                                    |
# | ע' פוגלמן      Administrative                                      0.091881                                    |
# |                National security, military, and the territories    0.087427                                    |
# | א' חיות        מ' נאור                                             0.085539                                    |
# | א' גרוניס      Social security, Health Insurance, Pension          0.082964                                    |
# | א' חיות        Civil                                               0.071827                                    |
# | א' רובינשטיין  ס' ג'ובראן                                          0.062746                                    |
# | ד' ביניש       Religious                                           0.061993                                    |
# | א' רובינשטיין  Civil                                               0.055491                                    |
# | א' גרוניס      מ' נאור                                             0.048946                                    |
# | י' עמית        Administrative                                      0.048324                                    |
# | א' חיות        ע' פוגלמן                                           0.045745                                    |
# | נ' הנדל        Administrative                                      0.043163                                    |
# | ח' מלצר        Administrative                                      0.042701                                    |
# | נ' הנדל        Civil                                               0.042377                                    |
# | ע' פוגלמן      י' עמית                                             0.037967                                    |
# | ח' מלצר        National security, military, and the territories    0.036593                                    |
# | א' רובינשטיין  Administrative                                      0.031267                                    |
# | ע' פוגלמן      Civil                                               0.027047                                    |
# | מ' נאור        National security, military, and the territories    0.022227                                    |
# |                Social security, Health Insurance, Pension          0.020044                                    |
# | ד' ביניש       National security, military, and the territories    0.018716                                    |
# | א' חיות        א' גרוניס                                           0.017669                                    |
# |                Social security, Health Insurance, Pension          0.016603                                    |
# | נ' הנדל        Family                                              0.016308                                    |
# | ח' מלצר        International law                                   0.013956                                    |
# | א' רובינשטיין  Criminal                                            0.013228                                    |
# | Name: 0, dtype: float64                                                                                        |
# +----------------------------------------------------------------------------------------------------------------+
# | National security, military, and the territories  Social security, Health Insurance, Pension         -0.230569 |
# | Constitutional                                    Social security, Health Insurance, Pension         -0.212089 |
# | Civil                                             Social security, Health Insurance, Pension         -0.203368 |
# | Criminal                                          Social security, Health Insurance, Pension         -0.202477 |
# | Constitutional                                    National security, military, and the territories   -0.202473 |
# | Civil                                             National security, military, and the territories   -0.194148 |
# | Criminal                                          National security, military, and the territories   -0.193297 |
# | Constitutional                                    Civil                                              -0.178586 |
# |                                                   Criminal                                           -0.177803 |
# | ד' ביניש                                          י' עמית                                            -0.172220 |
# | Civil                                             Criminal                                           -0.170493 |
# | א' גרוניס                                         י' עמית                                            -0.155199 |
# | Administrative                                    Social security, Health Insurance, Pension         -0.153322 |
# |                                                   National security, military, and the territories   -0.146371 |
# | ד' ביניש                                          נ' הנדל                                            -0.145378 |
# | Constitutional                                    Administrative                                     -0.134639 |
# | ד' ביניש                                          א' רובינשטיין                                      -0.131072 |
# |                                                   ע' פוגלמן                                          -0.130334 |
# | Administrative                                    Civil                                              -0.129103 |
# | א' חיות                                           ס' ג'ובראן                                         -0.128941 |
# | Administrative                                    Criminal                                           -0.128537 |
# | ד' ביניש                                          ס' ג'ובראן                                         -0.125477 |
# |                                                   Civil                                              -0.122244 |
# | א' גרוניס                                         ד' ביניש                                           -0.119490 |
# | Labor and Employment                              Social security, Health Insurance, Pension         -0.117809 |
# | א' חיות                                           ד' ביניש                                           -0.115429 |
# |                                                   א' רובינשטיין                                      -0.112888 |
# | ד' ביניש                                          ח' מלצר                                            -0.112641 |
# | Labor and Employment                              National security, military, and the territories   -0.112468 |
# | ע' פוגלמן                                         ס' ג'ובראן                                         -0.111168 |
# | Name: 0, dtype: float64                                                                                        |
# +----------------------------------------------------------------------------------------------------------------+
#
# Top 30 
|
# | Name: 0, dtype: float64                                                                                        |
# +----------------------------------------------------------------------------------------------------------------+
#
# Top 30 Not Normalized Petitioners
# +----------------------------------------------------------------------------------------------------------------+
# | מדינת ישראל                                 Labor and Employment                                0.521314       |
# | המוקד להגנת הפרט מיסודה של ד"ר לוטה זלצברגר  National security, military, and the territories    0.430355      |
# | מדינת ישראל                                  Criminal                                            0.349556      |
# | פלונית                                       Civil                                               0.172930      |
# | המוקד להגנת הפרט                             National security, military, and the territories    0.156356      |
# | פלוני                                        Civil                                               0.143925      |
# | האגודה לזכויות האזרח בישראל                  Constitutional                                      0.122210      |
# | מדינת ישראל                                  Social security, Health Insurance, Pension          0.115633      |
# | הפניקס חברה לביטוח בע"מ                      Religious                                           0.108448      |
# | פלונית                                       Administrative                                      0.108345      |
# | בעצמו                                        Civil                                               0.069377      |
# | פלוני                                        פלונית                                              0.051593      |
# | הפניקס חברה לביטוח בע"מ                      Social security, Health Insurance, Pension          0.050369      |
# | פלונית                                       Religious                                           0.050205      |
# | פלוני                                        National security, military, and the territories    0.050075      |
# | הפניקס חברה לביטוח בע"מ                      International law                                   0.048714      |
# |                                              Administrative                                      0.046635      |
# | פלונית                                       Family                                              0.045802      |
# | פלוני                                        Administrative                                      0.043754      |
# | בעצמו                                        Constitutional                                      0.041078      |
# | האגודה לזכויות האזרח בישראל                  National security, military, and the territories    0.039940      |
# | בעצמו                                        Administrative                                      0.038202      |
# | פלונית                                       Constitutional                                      0.038057      |
# | פלוני                                        Family                                              0.030444      |
# |                                              Constitutional                                      0.027938      |
# |  בעצמו                                       Civil                                               0.027685      |
# |                                              Administrative                                      0.024611      |
# | האגודה לזכויות האזרח בישראל                  Administrative                                      0.020536      |
# |  מדינת ישראל                                 Religious                                           0.018890      |
# |  בעצמו                                       Labor and Employment                                0.016783      |
# | Name: 0, dtype: float64                                                                                        |
# +----------------------------------------------------------------------------------------------------------------+
# | פלוני                                             מדינת ישראל                                        -0.567313 |
# | Criminal                                          Social security, Health Insurance, Pension         -0.321948 |
# | מדינת ישראל                                       פלונית                                             -0.298727 |
# | Criminal                                          National security, military, and the territories   -0.298407 |
# | National security, military, and the territories  Social security, Health Insurance, Pension         -0.270345 |
# | Constitutional                                    Criminal                                           -0.250711 |
# | מדינת ישראל                                       National security, military, and the territories   -0.240407 |
# |                                                   המוקד להגנת הפרט מיסודה של ד"ר לוטה זלצברגר        -0.237473 |
# | Constitutional                                    Social security, Health Insurance, Pension         -0.227135 |
# |                                                   National security, military, and the territories   -0.210526 |
# | מדינת ישראל                                        מדינת ישראל                                       -0.183650 |
# | פלוני                                             המוקד להגנת הפרט מיסודה של ד"ר לוטה זלצברגר        -0.180090 |
# | מדינת ישראל                                       Civil                                              -0.171531 |
# | המוקד להגנת הפרט מיסודה של ד"ר לוטה זלצברגר       Criminal                                           -0.160732 |
# | פלונית                                            Criminal                                           -0.158282 |
# | מדינת ישראל                                       Labor and Employment                               -0.157206 |
# | Civil                                             Criminal                                           -0.152717 |
# | פלוני                                              מדינת ישראל                                       -0.148243 |
# | Civil                                             Social security, Health Insurance, Pension         -0.138356 |
# | Labor and Employment                              Criminal                                           -0.134192 |
# | Civil                                             National security, military, and the territories   -0.128239 |
# | מדינת ישראל                                       האגודה לזכויות האזרח בישראל                        -0.123310 |
# |                                                    בעצמו                                             -0.123269 |
# | Labor and Employment                              Social security, Health Insurance, Pension         -0.121573 |
# |                                                   National security, military, and the territories   -0.112684 |
# | מדינת ישראל                                       Administrative                                     -0.111117 |
# | פלוני                                             Criminal                                           -0.107819 |
# | Constitutional                                    Civil                                              -0.107742 |
# | מדינת ישראל                                       בעצמו                                              -0.107506 |
# | Administrative                                    Criminal                                           -0.105268 |
# | Name: 0, dtype: float64                                                                                        |
# +----------------------------------------------------------------------------------------------------------------+
#
# Top 30 Normalized Petitioners
# +----------------------------------------------------------------------------------------------------------------+
# | המוקד להגנת הפרט מיסודה של ד"ר לוטה זלצברגר  National security, military, and the territories    0.421376      |
# | מדינת ישראל                                  Criminal                                            0.325338      |
# | פלונית                                       Civil                                               0.167632      |
# | המוקד להגנת הפרט                             National security, military, and the territories    0.144591      |
# | פלוני                                        Civil                                               0.136251      |
# | האגודה לזכויות האזרח בישראל                  Constitutional                                      0.111294      |
# | הפניקס חברה לביטוח בע"מ                      Religious                                           0.108199      |
# | פלונית                                       Administrative                                      0.097517      |
# | התנועה למען איכות השלטון בישראל              Administrative                                      0.096478      |
# | מדינת ישראל                                  Social security, Health Insurance, Pension          0.094913      |
# | בעצמו                                        Civil                                               0.065147      |
# | התנועה למען איכות השלטון בישראל              Constitutional                                      0.061538      |
# | כלל חברה לביטוח בע"מ                         Civil                                               0.058222      |
# | פלוני                                        פלונית                                              0.055403      |
# | הפניקס חברה לביטוח בע"מ                      Social security, Health Insurance, Pension          0.048387      |
# |                                              International law                                   0.047502      |
# | פלונית                                       Religious                                           0.046704      |
# | פלוני                                        National security, military, and the territories    0.046476      |
# | פלונית                                       Family                                              0.045564      |
# | האגודה לזכויות האזרח בישראל                  National security, military, and the territories    0.045213      |
# | הפניקס חברה לביטוח בע"מ                      Administrative                                      0.042468      |
# | כלל חברה לביטוח בע"מ                         Labor and Employment                                0.042136      |
# | בעצמו                                        Administrative                                      0.039866      |
# | כלל חברה לביטוח בע"מ                         Social security, Health Insurance, Pension          0.039822      |
# | פלונית                                       Constitutional                                      0.035986      |
# | פלוני                                        Administrative                                      0.032003      |
# | בעצמו                                        Constitutional                                      0.030679      |
# | פלוני                                        Family                                              0.030429      |
# | כלל חברה לביטוח בע"מ                         Religious                                           0.029918      |
# | התנועה למען איכות השלטון בישראל              Labor and Employment                                0.026587      |
# | Name: 0, dtype: float64                                                                                        |
# +----------------------------------------------------------------------------------------------------------------+
# | פלוני                                             מדינת ישראל                                        -0.591682 |
# | Criminal                                          Social security, Health Insurance, Pension         -0.312592 |
# | מדינת ישראל                                       פלונית                                             -0.311619 |
# | Criminal                                          National security, military, and the territories   -0.289812 |
# | National security, military, and the territories  Social security, Health Insurance, Pension         -0.268310 |
# | מדינת ישראל                                       National security, military, and the territories   -0.250853 |
# |                                                   המוקד להגנת הפרט מיסודה של ד"ר לוטה זלצברגר        -0.245299 |
# | Constitutional                                    Criminal                                           -0.244748 |
# |                                                   Social security, Health Insurance, Pension         -0.226589 |
# |                                                   National security, military, and the territories   -0.210077 |
# | מדינת ישראל                                       Civil                                              -0.180891 |
# | פלוני                                             המוקד להגנת הפרט מיסודה של ד"ר לוטה זלצברגר        -0.173628 |
# | מדינת ישראל                                       בעצמו                                              -0.170577 |
# | המוקד להגנת הפרט מיסודה של ד"ר לוטה זלצברגר       Criminal                                           -0.152957 |
# | פלונית                                            Criminal                                           -0.149620 |
# | Civil                                             Criminal                                           -0.149076 |
# | Labor and Employment                              Criminal                                           -0.144309 |
# | מדינת ישראל                                       האגודה לזכויות האזרח בישראל                        -0.142301 |
# | Civil                                             Social security, Health Insurance, Pension         -0.138016 |
# | Labor and Employment                              Social security, Health Insurance, Pension         -0.133602 |
# | Constitutional                                    Criminal                                           -0.153461 |
# | Criminal                                          Social security, Health Insurance, Pension         -0.153388 |
# | Labor and Employment                              Civil                                              -0.147868 |
# |                                                   Criminal                                           -0.147205 |
# |  בעצמו                                            עו"ד אביגדור פלדמן                                 -0.140646 |
# | בעצמו                                             בעצמה                                              -0.139843 |
# | Civil                                             National security, military, and the territories   -0.132798 |
# | Criminal                                          National security, military, and the territories   -0.132203 |
# | בעצמו                                             Labor and Employment                               -0.127592 |
# |  בעצמו                                             עו"ד אנדרה רוזנטל                                 -0.123778 |
# |                                                   עו"ד מחמוד ג'בארין                                 -0.122985 |
# | Constitutional                                    Religious                                          -0.117699 |
# | Religious                                         Social security, Health Insurance, Pension         -0.117643 |
# | בעצמו                                             עו"ד אשרף אבו סנינה                                -0.115019 |
# | Name: 0, dtype: float64                                                                                        |
# +----------------------------------------------------------------------------------------------------------------+
#
# Top 30 Normalized Petitioners Attorneys
# +----------------------------------------------------------------------------------------------------------------+
# | מחמוד גבארין   National security, military, and the territories    0.382448                                    |
# | אנדרה רוזנטל   National security, military, and the territories    0.255299                                    |
# | לאה צמל        National security, military, and the territories    0.127943                                    |
# | אביגדור פלדמן  Criminal                                            0.126229                                    |
# | דוד גולן       Criminal                                            0.119011                                    |
# | עמוס גבעון     Civil                                               0.098420                                    |
# | דוד גולן       Civil                                               0.075323                                    |
# | בעצמו          Labor and Employment                                0.074804                                    |
# |                Social security, Health Insurance, Pension          0.061989                                    |
# | בעצמה          Religious                                           0.059481                                    |
# | אביגדור פלדמן  National security, military, and the territories    0.051700                                    |
# | בעצמם          Civil                                               0.051447                                    |
# |                Administrative                                      0.048460                                    |
# | בעצמו          Constitutional                                      0.047722                                    |
# | אליעד שרגא     Administrative                                      0.046988                                    |
# | בעצמו          Religious                                           0.046024                                    |
# | אליעד שרגא     National security, military, and the territories    0.044767                                    |
# |                International law                                   0.039498                                    |
# | עמוס גבעון     Labor and Employment                                0.038710                                    |
# | בעצמה          International law                                   0.038220                                    |
# | לאה צמל        Criminal                                            0.031339                                    |
# | אליעד שרגא     Constitutional                                      0.026903                                    |
# | אביגדור פלדמן  Constitutional                                      0.026650                                    |
# | בעצמה          Constitutional                                      0.026516                                    |
# | אביגדור פלדמן  International law                                   0.025500                                    |
# | בעצמה          Social security, Health Insurance, Pension          0.024346                                    |
# | עמוס גבעון     Criminal                                            0.019000                                    |
# | בעצמו          Family                                              0.017441                                    |
# | בעצמה          Civil                                               0.013927                                    |
# | בעצמם          Constitutional                                      0.012283                                    |
# | Name: 0, dtype: float64                                                                                        |
# +----------------------------------------------------------------------------------------------------------------+
# | בעצמו                                             בעצמה                                              -0.477770 |
# |                                                   בעצמם                                              -0.331664 |
# |                                                   אביגדור פלדמן                                      -0.269766 |
# |                                                   דוד גולן                                           -0.244011 |
# | Constitutional                                    Social security, Health Insurance, Pension         -0.236648 |
# | בעצמו                                             אנדרה רוזנטל                                       -0.232091 |
# |                                                   מחמוד גבארין                                       -0.228290 |
# | Labor and Employment                              Social security, Health Insurance, Pension         -0.227318 |
# |                                                   Constitutional                                     -0.225185 |
# | בעצמו                                             לאה צמל                                            -0.207074 |
# |                                                   אליעד שרגא                                         -0.200214 |
# |                                                   National security, military, and the territories   -0.198757 |
# | National security, military, and the territories  Social security, Health Insurance, Pension         -0.198702 |
# | Constitutional                                    National security, military, and the territories   -0.196838 |
# | בעצמו                                             עמוס גבעון                                         -0.193815 |
# | Labor and Employment                              National security, military, and the territories   -0.189078 |
# | Criminal                                          Social security, Health Insurance, Pension         -0.163754 |
# | Constitutional                                    Criminal                                           -0.162218 |
# | Civil                                             Social security, Health Insurance, Pension         -0.159776 |
# | Constitutional                                    Civil                                              -0.158277 |
# | Labor and Employment                              Criminal                                           -0.155822 |
# |                                                   Civil                                              -0.152037 |
# | Criminal                                          National security, military, and the territories   -0.136207 |
# | Civil                                             National security, military, and the territories   -0.132898 |
# | Religious                                         Social security, Health Insurance, Pension         -0.112595 |
# | Constitutional                                    Religious                                          -0.111538 |
# | Civil                                             Criminal                                           -0.109523 |
# | Labor and Employment                              Religious                                          -0.107141 |
# | Administrative                                    Social security, Health Insurance, Pension         -0.106942 |
# | Constitutional                                    Administrative                                     -0.105938 |
# | Name: 0, dtype: float64                                                                                        |
# +----------------------------------------------------------------------------------------------------------------+
#
# Top 30 Not Normalized Defense
# +----------------------------------------------------------------------------------------------------------------+
# | מדינת ישראל         Labor and Employment                                0.563359                               |
# | מדינת ישראל          Criminal                                            0.317608                              |
# | שר הפנים             National security, military, and the territories    0.307228                              |
# | שר הביטחון           National security, military, and the territories    0.221112                              |
# | כונס הנכסים הרשמי    Civil                                               0.219948                              |
# | פלוני                פלונית                                              0.158716                              |
# | משרד הפנים           Administrative                                      0.152023                              |
# |                      National security, military, and the territories    0.149468                              |
# | שר הפנים             Administrative                                      0.115043                              |
# | פלונית               Civil                                               0.102903                              |
# | הוגש הליך            Constitutional                                      0.075524                              |
# | שר הפנים             משרד הפנים                                          0.073885                              |
# | הוגש הליך            Social security, Health Insurance, Pension          0.073640                              |
# | היועץ המשפטי לממשלה  Constitutional                                      0.068946                              |
# | כונס הנכסים הרשמי    Social security, Health Insurance, Pension          0.062039                              |
# | מדינת ישראל          Religious                                           0.059988                              |
# | פלוני                Social security, Health Insurance, Pension          0.051563                              |
# |                      Civil                                               0.050615                              |
# | מדינת ישראל          Social security, Health Insurance, Pension          0.049883                              |
# | היועץ המשפטי לממשלה  National security, military, and the territories    0.044244                              |
# | כונס הנכסים הרשמי    Family                                              0.043359                              |
# | היועץ המשפטי לממשלה  Administrative                                      0.041344                              |
# | כונס הנכסים הרשמי    International law                                   0.037315                              |
# | פלוני                Criminal                                            0.036646                              |
# ...
# | Administrative                                    National security, military, and the territories   -0.119994 |
# | Civil                                             Criminal                                           -0.119897 |
# | Constitutional                                    Civil                                              -0.119835 |
# | משרד הפנים                                        Criminal                                           -0.115492 |
# | Administrative                                    Social security, Health Insurance, Pension         -0.115379 |
# | שר הפנים                                          כונס הנכסים הרשמי                                  -0.114174 |
# | Name: 0, dtype: float64                                                                                        |
# +----------------------------------------------------------------------------------------------------------------+
#
# Top 30 Not Normalized Defense Attorneys
# +----------------------------------------------------------------------------------------------------------------+
# | בעצמו                  Civil                                               0.397564                            |
# |  בעצמו                 Labor and Employment                                0.245378                            |
# |                        Social security, Health Insurance, Pension          0.179113                            |
# |                        Criminal                                            0.150027                            |
# | עו"ד יצחק ברט          Administrative                                      0.142669                            |
# | בעצמו                  Social security, Health Insurance, Pension          0.139202                            |
# | עו"ד הדס ערן           National security, military, and the territories    0.136121                            |
# | עו"ד רן רוזנברג        Constitutional                                      0.117945                            |
# | Administrative                                    Civil                                              -0.112685 |
# | Name: 0, dtype: float64                                                                                        |
# +----------------------------------------------------------------------------------------------------------------+

# %%
def plot_correlation(df,title):
    columns=list()
    for col in df.columns:
        if any("\u0590" <= c <= "\u05EA" for c in col):
            rev_col = col[::-1]
            columns.append(rev_col)
        else:
            columns.append(col)
    
    sns.set_theme(style="white")

    # Compute the correlation matrix
    corr = df.corr()
    
    # Generate a mask for the upper triangle
    mask = np.triu(np.ones_like(corr, dtype=bool))
    
    # Set up the matplotlib figure
    f, ax = plt.subplots(figsize=(11, 9))
    
    # Generate a custom diverging colormap
    cmap = sns.diverging_palette(230, 20, as_cmap=True)
    
    # Draw the heatmap with the mask and correct aspect ratio
    heatmap=sns.heatmap(corr, mask=mask,  vmax=.3, vmin=-.3,center=0,
                square=True, linewidths=.5, cbar_kws={"shrink": .5})
    heatmap.set_xticklabels(columns)
    heatmap.set_yticklabels(columns)
    heatmap.set_title(f'Correlation Heatmap - {title}', fontdict={'fontsize':25}, pad=25)

# %%
def plot_corr_mat(df,role):    
    columns=list()
    for col in df.columns:
        if any("\u0590" <= c <= "\u05EA" for c in col):
            rev_col = col[::-1]
            columns.append(rev_col)
        else:
            columns.append(col)
    
    sns.set_theme(style="white")
    sns.set_context("paper", font_scale=2)
    
    plt.figure(figsize=(30, 15))
    corr = df.corr()
    
    
    # Generate a mask for the upper triangle
    maskk = np.triu(np.ones_like(corr, dtype=bool))
    
    # Generate a custom diverging colormap
    cmapp = sns.diverging_palette(230, 20, as_cmap=True)
    
    heatmap = sns.heatmap(corr,mask=maskk,cmap=cmapp, vmin=-.3, vmax=.3, annot=True,square = True, 
                          linewidths=1, cbar_kws={"shrink": 1}, annot_kws={'size': 15, 'weight': 'bold'})
    heatmap.set_xticklabels(columns)
    heatmap.set_yticklabels(columns)
    heatmap.set_title(f'Correlation Heatmap - {role}', fontdict={'fontsize':25}, pad=25)
    
    for t in heatmap.texts:
        if float(t.get_text())>=0.1 or float(t.get_text())<=-0.1:
            t.set_text(t.get_text()) 
        else:
            t.set_text("")

# %%
plot_corr_mat(jn,'Not Normalized Judges')

# %%
#plot_correlation(jn,'Not Normalized Judges')

# %%
plot_corr_mat(j,'Normalized Judges')

# %%
#plot_correlation(j,'Normalized Judges')

# %%
plot_corr_mat(pn,'Not Normalized Petitioner')

# %%
#plot_correlation(pn,'Not Normalized Petitioner')

# %%
plot_corr_mat(p,'Normalized Petitioner')

# %%
#plot_correlation(p,'Normalized Petitioner')

# %%
plot_corr_mat(pan,'Not Normalized Petitioner Attorneys')

# %%
#plot_correlation(pan,'Not Normalized Petitioner Attorneys')

# %%
plot_corr_mat(pa,'Normalized Petitioner Attorneys')

# %%
#plot_correlation(pa,'Normalized Petitioner Attorneys')

# %%
plot_corr_mat(dn,'Not Normalized Defense')

# %%
#plot_correlation(dn,'Not Normalized Defense')

# %%
plot_corr_mat(d,'Normalized Defense')

# %%
#plot_correlation(d,'Normalized Defense')

# %%
plot_corr_mat(dan,'Not Normalized Defense Attorneys')

# %%
#plot_correlation(dan,'Not Normalized Defense Attorneys')

# %%
plot_corr_mat(da,'Normalized Defense Attorneys')

# %%
#plot_correlation(da,'Normalized Defense Attorneys')
